# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test_input = np.load('H:/University/Semester_10/Bachelor Project/Data/archive/data(processed)/test_input.npy')
test_output = np.load('H:/University/Semester_10/Bachelor Project/Data/archive/data(processed)/test_output.npy')
train_input = np.load('H:/University/Semester_10/Bachelor Project/Data/archive/data(processed)/train_input.npy')
train_output = np.load('H:/University/Semester_10/Bachelor Project/Data/archive/data(processed)/train_output.npy')
val_input = np.load('H:/University/Semester_10/Bachelor Project/Data/archive/data(processed)/val_input.npy')
val_output = np.load('H:/University/Semester_10/Bachelor Project/Data/archive/data(processed)/val_output.npy')

# %%
train_input.shape, train_output.shape, val_input.shape, val_output.shape, test_input.shape, test_output.shape
# Out:
# ((570, 256, 256),
#  (570, 256, 256),
#  (90, 256, 256),
#  (90, 256, 256),
#  (150, 256, 256),
#  (150, 256, 256))

# %%
plt.imshow(test_input[0])

# %%
plt.imshow(test_output[0])
